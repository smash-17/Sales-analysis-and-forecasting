# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# loading the data 
sales_data = pd.read_csv('/content/drive/MyDrive/Train (1).csv')
#checking the first 5 rows of the dataframe
sales_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
sales_data.shape
# Out:
# (8523, 12)

# %%
# getting some information about the dataset
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
sales_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
sales_data['Item_Weight'].mean()
# Out:
# 12.857645184135976

# %%
sales_data['Item_Weight'].fillna(sales_data['Item_Weight'].mean(), inplace=True)

# %%
sales_data['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
mode_of_Outlet_size = sales_data.pivot_table(values='Outlet_Size', columns='Outlet_Type', aggfunc=(lambda x: x.mode()[0]))

# %%
miss_values = sales_data['Outlet_Size'].isnull()

# %%
sales_data.loc[miss_values, 'Outlet_Size'] = sales_data.loc[miss_values,'Outlet_Type'].apply(lambda x: mode_of_Outlet_size[x])

# %%
sales_data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
sales_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
sales_data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
encoder = LabelEncoder()

# %%
sales_data['Item_Identifier'] = encoder.fit_transform(sales_data['Item_Identifier'])

sales_data['Item_Fat_Content'] = encoder.fit_transform(sales_data['Item_Fat_Content'])

sales_data['Item_Type'] = encoder.fit_transform(sales_data['Item_Type'])

sales_data['Outlet_Identifier'] = encoder.fit_transform(sales_data['Outlet_Identifier'])

sales_data['Outlet_Size'] = encoder.fit_transform(sales_data['Outlet_Size'])

sales_data['Outlet_Location_Type'] = encoder.fit_transform(sales_data['Outlet_Location_Type'])

sales_data['Outlet_Type'] = encoder.fit_transform(sales_data['Outlet_Type'])

# %%
sales_data.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 1         0.016047          4
# 1                8         5.92                 2         0.019278         14
# 2              662        17.50                 1         0.016760         10
# 3             1121        19.20                 2         0.000000          6
# 4             1297         8.93                 1         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            1
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            2
# 4   53.8614                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# 2                     0            1          2097.2700
# 3                     2            0           732.3800
# 4                     2            1           994.7052

# %%
#Let's have all the features in X & target in Y
X = sales_data.drop(columns='Item_Outlet_Sales', axis=1)
y = sales_data['Item_Outlet_Sales']

# %%
X.shape
# Out:
# (8523, 11)

# %%
y.shape
# Out:
# (8523,)

# %%
x_train = X.iloc[0:6822] # 80%
x_test = X.iloc[6822:] # 20%
y_train = y.iloc[0:6822] # 80%
y_test = y.iloc[6822:] # 20%
print(type(x_train))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (6822, 11)
# (1701, 11)
# (6822,)
# (1701,)

# %%
x_train.head(100)
# Out:
#     Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               156     9.300000                 1         0.016047
# 1                 8     5.920000                 2         0.019278
# 2               662    17.500000                 1         0.016760
# 3              1121    19.200000                 2         0.000000
# 4              1297     8.930000                 1         0.000000
# ..              ...          ...               ...              ...
# 95              970    12.857645                 1         0.009715
# 96              382    12.150000                 1         0.131384
# 97              231     8.750000                 2         0.074613
# 98             1442    12.857645                 1         0.028460
# 99              231     8.750000                 2         0.074627
#
#     Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0           4  249.8092                  9                       1999
# 1          14   48.2692                  3                       2009
# 2          10  141.6180                  9                       1999
# 3           6  182.0950                  0                       1998
# 4           9   53.8614                  1                       1987
# ..        ...       ...                ...                        ...
# 95          5  120.0414                  4                       1985
# 96          5  246.0460                  9                       1999
# 97          6  187.4556                  6                       2004
# 98          9  149.9708                  5                       1985
# 99          6  187.8556                  8                       1997
#
#     Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0             1                     0            1
# 1             1                     2            2
# 2             1                     0            1
# 3             2                     2            0
# 4             0                     2            1
# ..          ...                   ...          ...
# 95            2                     0            0
# 96            1                     0            1
# 97            2                     1            1
# 98            1                     2            3
# 99            2                     0            1
#
# [100 rows x 11 columns]

# %%
import numpy as np

x_train = np.asarray(x_train).astype(np.float32)
x_test = np.asarray(x_test).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

# %%
mea = np.mean(x_train,axis = 0)
std = np.std(x_train,axis = 0)
x_train = (x_train-mea)/std
x_test = (x_test-mea)/std

# %%
#combining 1dcnn and lstm

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError
import tensorflow as tf

def get_model(params, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=params["filters"], kernel_size=params["kernel_size"], activation=params["activation"], input_shape=(input_shape, 1)))
    model.add(MaxPooling1D(pool_size=params["pool_size"]))

    model.add(LSTM(units=params["lstm_units"], return_sequences=True))
    model.add(Dropout(rate=params["dropout"]))

    model.add(Flatten())
    model.add(Dense(units=params["dense_units"], activation=params["activation"]))
    model.add(Dropout(rate=params["dropout"]))

    model.add(Dense(units=1, activation=params["output_activation"]))

    model.compile(loss=params["loss"],
                  optimizer=tf.keras.optimizers.Adam(learning_rate=params["learning_rate"]),
                  metrics=[RootMeanSquaredError(), MeanAbsoluteError()])

    return model

params = {
    "loss": "mean_squared_error",
    "activation": "relu",
    "output_activation": "linear",
    "learning_rate": 0.003,
    "dropout": 0.2,
    "filters": 32,
    "kernel_size": 3,
    "pool_size": 2,
    "lstm_units": 64,
    "dense_units": 32,
    "epochs": 100,
    "batch_size": 128,
    "es_patience": 10
}

model = get_model(params=params, input_shape=x_train.shape[1])

es_callback = EarlyStopping(monitor='val_root_mean_squared_error',
                            mode='min',
                            patience=params["es_patience"])

history = model.fit(x_train,
                    y_train,
                    validation_data=(x_test, y_test),
                    epochs=params["epochs"],
                    batch_size=params["batch_size"],
                    verbose=1,
                    callbacks=[es_callback])
# Out:
# Epoch 1/100
# 54/54 [==============================] - 4s 21ms/step - loss: 7253567.5000 - root_mean_squared_error: 2693.2449 - mean_absolute_error: 2089.2737 - val_loss: 6408032.5000 - val_root_mean_squared_error: 2531.4092 - val_mean_absolute_error: 1875.4194
# Epoch 2/100
# 54/54 [==============================] - 1s 11ms/step - loss: 5310051.0000 - root_mean_squared_error: 2304.3547 - mean_absolute_error: 1671.0262 - val_loss: 4212143.5000 - val_root_mean_squared_error: 2052.3508 - val_mean_absolute_error: 1453.0542
# Epoch 3/100
# 54/54 [==============================] - 1s 11ms/step - loss: 3507502.5000 - root_mean_squared_error: 1872.8328 - mean_absolute_error: 1357.7228 - val_loss: 3112628.5000 - val_root_mean_squared_error: 1764.2643 - val_mean_absolute_error: 1321.7026
# Epoch 4/100
# 54/54 [==============================] - 1s 11ms/step - loss: 3012743.5000 - root_mean_squared_error: 1735.7256 - mean_absolute_error: 1341.8049 - val_loss: 2976644.0000 - val_root_mean_squared_error: 1725.2953 - val_mean_absolute_error: 1347.1802
# Epoch 5/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2942627.7500 - root_mean_squared_error: 1715.4089 - mean_absolute_error: 1341.0378 - val_loss: 2967795.0000 - val_root_mean_squared_error: 1722.7289 - val_mean_absolute_error: 1351.5411
# Epoch 6/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2939386.7500 - root_mean_squared_error: 1714.4640 - mean_absolute_error: 1347.2927 - val_loss: 2961217.2500 - val_root_mean_squared_error: 1720.8187 - val_mean_absolute_error: 1347.8726
# Epoch 7/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2927124.5000 - root_mean_squared_error: 1710.8842 - mean_absolute_error: 1345.1271 - val_loss: 2953938.0000 - val_root_mean_squared_error: 1718.7024 - val_mean_absolute_error: 1349.9119
# Epoch 8/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2947099.0000 - root_mean_squared_error: 1716.7117 - mean_absolute_error: 1351.0782 - val_loss: 2946246.7500 - val_root_mean_squared_error: 1716.4635 - val_mean_absolute_error: 1345.1569
# Epoch 9/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2938911.0000 - root_mean_squared_error: 1714.3252 - mean_absolute_error: 1345.8160 - val_loss: 2938609.0000 - val_root_mean_squared_error: 1714.2372 - val_mean_absolute_error: 1341.9791
# Epoch 10/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2905460.7500 - root_mean_squared_error: 1704.5413 - mean_absolute_error: 1338.0035 - val_loss: 2928377.5000 - val_root_mean_squared_error: 1711.2502 - val_mean_absolute_error: 1342.4194
# Epoch 11/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2923432.2500 - root_mean_squared_error: 1709.8047 - mean_absolute_error: 1345.8613 - val_loss: 2916542.5000 - val_root_mean_squared_error: 1707.7888 - val_mean_absolute_error: 1335.8871
# Epoch 12/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2883680.7500 - root_mean_squared_error: 1698.1404 - mean_absolute_error: 1331.0101 - val_loss: 2903231.7500 - val_root_mean_squared_error: 1703.8872 - val_mean_absolute_error: 1334.4419
# Epoch 13/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2877778.7500 - root_mean_squared_error: 1696.4017 - mean_absolute_error: 1328.4043 - val_loss: 2890403.2500 - val_root_mean_squared_error: 1700.1187 - val_mean_absolute_error: 1334.2466
# Epoch 14/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2850755.7500 - root_mean_squared_error: 1688.4181 - mean_absolute_error: 1329.8345 - val_loss: 2878469.7500 - val_root_mean_squared_error: 1696.6053 - val_mean_absolute_error: 1325.3408
# Epoch 15/100
# 54/54 [==============================] - 1s 12ms/step - loss: 2840472.7500 - root_mean_squared_error: 1685.3702 - mean_absolute_error: 1322.0885 - val_loss: 2863617.5000 - val_root_mean_squared_error: 1692.2227 - val_mean_absolute_error: 1322.7184
# Epoch 16/100
# 54/54 [==============================] - 1s 15ms/step - loss: 2845624.2500 - root_mean_squared_error: 1686.8978 - mean_absolute_error: 1326.5577 - val_loss: 2847392.2500 - val_root_mean_squared_error: 1687.4218 - val_mean_absolute_error: 1317.9111
# Epoch 17/100
# 54/54 [==============================] - 1s 15ms/step - loss: 2796170.0000 - root_mean_squared_error: 1672.1752 - mean_absolute_error: 1311.2854 - val_loss: 2830497.0000 - val_root_mean_squared_error: 1682.4081 - val_mean_absolute_error: 1319.1090
# Epoch 18/100
# 54/54 [==============================] - 1s 15ms/step - loss: 2802341.5000 - root_mean_squared_error: 1674.0195 - mean_absolute_error: 1319.8330 - val_loss: 2813245.5000 - val_root_mean_squared_error: 1677.2732 - val_mean_absolute_error: 1307.4054
# Epoch 19/100
# 54/54 [==============================] - 1s 14ms/step - loss: 2787775.0000 - root_mean_squared_error: 1669.6631 - mean_absolute_error: 1310.4290 - val_loss: 2799018.0000 - val_root_mean_squared_error: 1673.0266 - val_mean_absolute_error: 1302.9482
# Epoch 20/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2771064.5000 - root_mean_squared_error: 1664.6515 - mean_absolute_error: 1301.7758 - val_loss: 2774642.0000 - val_root_mean_squared_error: 1665.7257 - val_mean_absolute_error: 1303.6591
# Epoch 21/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2733540.7500 - root_mean_squared_error: 1653.3423 - mean_absolute_error: 1292.1095 - val_loss: 2747668.2500 - val_root_mean_squared_error: 1657.6093 - val_mean_absolute_error: 1298.6068
# Epoch 22/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2728100.5000 - root_mean_squared_error: 1651.6963 - mean_absolute_error: 1297.6019 - val_loss: 2723601.0000 - val_root_mean_squared_error: 1650.3336 - val_mean_absolute_error: 1285.1356
# Epoch 23/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2683953.7500 - root_mean_squared_error: 1638.2777 - mean_absolute_error: 1286.4097 - val_loss: 2722701.0000 - val_root_mean_squared_error: 1650.0609 - val_mean_absolute_error: 1280.6140
# Epoch 24/100
# 54/54 [==============================] - 1s 12ms/step - loss: 2668360.5000 - root_mean_squared_error: 1633.5117 - mean_absolute_error: 1282.1884 - val_loss: 2685399.0000 - val_root_mean_squared_error: 1638.7188 - val_mean_absolute_error: 1281.4972
# Epoch 25/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2648088.2500 - root_mean_squared_error: 1627.2948 - mean_absolute_error: 1276.5450 - val_loss: 2658821.7500 - val_root_mean_squared_error: 1630.5894 - val_mean_absolute_error: 1268.1002
# Epoch 26/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2622136.5000 - root_mean_squared_error: 1619.3013 - mean_absolute_error: 1269.0192 - val_loss: 2635283.5000 - val_root_mean_squared_error: 1623.3556 - val_mean_absolute_error: 1265.7188
# Epoch 27/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2616937.0000 - root_mean_squared_error: 1617.6949 - mean_absolute_error: 1261.8563 - val_loss: 2617925.7500 - val_root_mean_squared_error: 1618.0005 - val_mean_absolute_error: 1272.2961
# Epoch 28/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2572454.5000 - root_mean_squared_error: 1603.8873 - mean_absolute_error: 1256.1705 - val_loss: 2583446.0000 - val_root_mean_squared_error: 1607.3102 - val_mean_absolute_error: 1254.0410
# Epoch 29/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2544564.0000 - root_mean_squared_error: 1595.1689 - mean_absolute_error: 1246.3383 - val_loss: 2547636.5000 - val_root_mean_squared_error: 1596.1317 - val_mean_absolute_error: 1249.1312
# Epoch 30/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2513293.0000 - root_mean_squared_error: 1585.3369 - mean_absolute_error: 1240.6725 - val_loss: 2518083.0000 - val_root_mean_squared_error: 1586.8469 - val_mean_absolute_error: 1227.4766
# Epoch 31/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2486268.0000 - root_mean_squared_error: 1576.7904 - mean_absolute_error: 1230.4664 - val_loss: 2491038.7500 - val_root_mean_squared_error: 1578.3025 - val_mean_absolute_error: 1225.2710
# Epoch 32/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2452130.0000 - root_mean_squared_error: 1565.9279 - mean_absolute_error: 1222.5618 - val_loss: 2464584.5000 - val_root_mean_squared_error: 1569.8995 - val_mean_absolute_error: 1218.9668
# Epoch 33/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2435169.2500 - root_mean_squared_error: 1560.5029 - mean_absolute_error: 1218.9512 - val_loss: 2435269.0000 - val_root_mean_squared_error: 1560.5348 - val_mean_absolute_error: 1208.4506
# Epoch 34/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2414059.5000 - root_mean_squared_error: 1553.7244 - mean_absolute_error: 1212.5769 - val_loss: 2450418.5000 - val_root_mean_squared_error: 1565.3812 - val_mean_absolute_error: 1195.4895
# Epoch 35/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2393275.0000 - root_mean_squared_error: 1547.0214 - mean_absolute_error: 1206.9709 - val_loss: 2427684.5000 - val_root_mean_squared_error: 1558.1029 - val_mean_absolute_error: 1181.6685
# Epoch 36/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2342778.7500 - root_mean_squared_error: 1530.6139 - mean_absolute_error: 1192.5702 - val_loss: 2362584.5000 - val_root_mean_squared_error: 1537.0701 - val_mean_absolute_error: 1180.2483
# Epoch 37/100
# 54/54 [==============================] - 1s 15ms/step - loss: 2346254.2500 - root_mean_squared_error: 1531.7488 - mean_absolute_error: 1190.4779 - val_loss: 2334343.7500 - val_root_mean_squared_error: 1527.8560 - val_mean_absolute_error: 1167.5913
# Epoch 38/100
# 54/54 [==============================] - 1s 15ms/step - loss: 2316024.7500 - root_mean_squared_error: 1521.8491 - mean_absolute_error: 1176.8357 - val_loss: 2305228.2500 - val_root_mean_squared_error: 1518.2979 - val_mean_absolute_error: 1160.1245
# Epoch 39/100
# 54/54 [==============================] - 1s 15ms/step - loss: 2250152.0000 - root_mean_squared_error: 1500.0507 - mean_absolute_error: 1164.7312 - val_loss: 2273583.5000 - val_root_mean_squared_error: 1507.8407 - val_mean_absolute_error: 1160.1899
# Epoch 40/100
# 54/54 [==============================] - 1s 15ms/step - loss: 2251487.5000 - root_mean_squared_error: 1500.4957 - mean_absolute_error: 1155.7537 - val_loss: 2248468.5000 - val_root_mean_squared_error: 1499.4894 - val_mean_absolute_error: 1152.4271
# Epoch 41/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2232470.0000 - root_mean_squared_error: 1494.1453 - mean_absolute_error: 1161.5127 - val_loss: 2232040.0000 - val_root_mean_squared_error: 1494.0013 - val_mean_absolute_error: 1156.2559
# Epoch 42/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2197448.5000 - root_mean_squared_error: 1482.3794 - mean_absolute_error: 1145.6311 - val_loss: 2214366.2500 - val_root_mean_squared_error: 1488.0747 - val_mean_absolute_error: 1156.8395
# Epoch 43/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2203878.7500 - root_mean_squared_error: 1484.5466 - mean_absolute_error: 1145.8074 - val_loss: 2185859.7500 - val_root_mean_squared_error: 1478.4653 - val_mean_absolute_error: 1132.7667
# Epoch 44/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2183403.2500 - root_mean_squared_error: 1477.6344 - mean_absolute_error: 1139.4775 - val_loss: 2172983.0000 - val_root_mean_squared_error: 1474.1041 - val_mean_absolute_error: 1139.0349
# Epoch 45/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2168461.7500 - root_mean_squared_error: 1472.5698 - mean_absolute_error: 1131.9240 - val_loss: 2171311.0000 - val_root_mean_squared_error: 1473.5369 - val_mean_absolute_error: 1140.5923
# Epoch 46/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2123319.0000 - root_mean_squared_error: 1457.1613 - mean_absolute_error: 1125.4678 - val_loss: 2178280.7500 - val_root_mean_squared_error: 1475.9000 - val_mean_absolute_error: 1117.8116
# Epoch 47/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2144731.2500 - root_mean_squared_error: 1464.4901 - mean_absolute_error: 1125.0667 - val_loss: 2107956.2500 - val_root_mean_squared_error: 1451.8802 - val_mean_absolute_error: 1106.1189
# Epoch 48/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2116139.7500 - root_mean_squared_error: 1454.6958 - mean_absolute_error: 1117.2491 - val_loss: 2093681.3750 - val_root_mean_squared_error: 1446.9559 - val_mean_absolute_error: 1112.1161
# Epoch 49/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2101975.0000 - root_mean_squared_error: 1449.8190 - mean_absolute_error: 1117.7051 - val_loss: 2085941.6250 - val_root_mean_squared_error: 1444.2789 - val_mean_absolute_error: 1113.8663
# Epoch 50/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2097173.5000 - root_mean_squared_error: 1448.1621 - mean_absolute_error: 1111.6689 - val_loss: 2106791.5000 - val_root_mean_squared_error: 1451.4791 - val_mean_absolute_error: 1129.9104
# Epoch 51/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2115576.7500 - root_mean_squared_error: 1454.5022 - mean_absolute_error: 1110.9315 - val_loss: 2057547.0000 - val_root_mean_squared_error: 1434.4152 - val_mean_absolute_error: 1088.2069
# Epoch 52/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2051378.5000 - root_mean_squared_error: 1432.2634 - mean_absolute_error: 1096.1130 - val_loss: 2033463.8750 - val_root_mean_squared_error: 1425.9957 - val_mean_absolute_error: 1087.9480
# Epoch 53/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2046655.3750 - root_mean_squared_error: 1430.6136 - mean_absolute_error: 1093.3530 - val_loss: 2025148.3750 - val_root_mean_squared_error: 1423.0770 - val_mean_absolute_error: 1091.9237
# Epoch 54/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2030451.2500 - root_mean_squared_error: 1424.9391 - mean_absolute_error: 1092.0875 - val_loss: 2010435.6250 - val_root_mean_squared_error: 1417.8983 - val_mean_absolute_error: 1080.6324
# Epoch 55/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2028719.1250 - root_mean_squared_error: 1424.3311 - mean_absolute_error: 1088.4001 - val_loss: 2023131.1250 - val_root_mean_squared_error: 1422.3682 - val_mean_absolute_error: 1064.2343
# Epoch 56/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2031382.2500 - root_mean_squared_error: 1425.2656 - mean_absolute_error: 1089.8934 - val_loss: 1997986.8750 - val_root_mean_squared_error: 1413.5016 - val_mean_absolute_error: 1077.1918
# Epoch 57/100
# 54/54 [==============================] - 1s 11ms/step - loss: 2046150.2500 - root_mean_squared_error: 1430.4371 - mean_absolute_error: 1093.7014 - val_loss: 1974174.7500 - val_root_mean_squared_error: 1405.0533 - val_mean_absolute_error: 1058.0989
# Epoch 58/100
# 54/54 [==============================] - 1s 15ms/step - loss: 2002006.1250 - root_mean_squared_error: 1414.9226 - mean_absolute_error: 1082.3705 - val_loss: 1959681.2500 - val_root_mean_squared_error: 1399.8861 - val_mean_absolute_error: 1060.5380
# Epoch 59/100
# 54/54 [==============================] - 1s 15ms/step - loss: 1977724.5000 - root_mean_squared_error: 1406.3159 - mean_absolute_error: 1074.2035 - val_loss: 1954635.3750 - val_root_mean_squared_error: 1398.0828 - val_mean_absolute_error: 1058.3352
# Epoch 60/100
# 54/54 [==============================] - 1s 15ms/step - loss: 1974840.7500 - root_mean_squared_error: 1405.2903 - mean_absolute_error: 1069.2006 - val_loss: 1931915.6250 - val_root_mean_squared_error: 1389.9337 - val_mean_absolute_error: 1058.1819
# Epoch 61/100
# 54/54 [==============================] - 1s 14ms/step - loss: 1982314.0000 - root_mean_squared_error: 1407.9468 - mean_absolute_error: 1076.5090 - val_loss: 1915616.3750 - val_root_mean_squared_error: 1384.0580 - val_mean_absolute_error: 1046.7292
# Epoch 62/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1944239.7500 - root_mean_squared_error: 1394.3600 - mean_absolute_error: 1059.2024 - val_loss: 1906973.5000 - val_root_mean_squared_error: 1380.9321 - val_mean_absolute_error: 1043.8801
# Epoch 63/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1934474.5000 - root_mean_squared_error: 1390.8539 - mean_absolute_error: 1064.7557 - val_loss: 1896871.0000 - val_root_mean_squared_error: 1377.2694 - val_mean_absolute_error: 1028.4443
# Epoch 64/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1943403.7500 - root_mean_squared_error: 1394.0602 - mean_absolute_error: 1061.0350 - val_loss: 1865346.8750 - val_root_mean_squared_error: 1365.7770 - val_mean_absolute_error: 1042.5385
# Epoch 65/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1927573.0000 - root_mean_squared_error: 1388.3706 - mean_absolute_error: 1059.9346 - val_loss: 1839694.1250 - val_root_mean_squared_error: 1356.3533 - val_mean_absolute_error: 1018.1150
# Epoch 66/100
# 54/54 [==============================] - 1s 10ms/step - loss: 1893731.7500 - root_mean_squared_error: 1376.1293 - mean_absolute_error: 1045.0580 - val_loss: 1842968.2500 - val_root_mean_squared_error: 1357.5597 - val_mean_absolute_error: 1003.7335
# Epoch 67/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1859897.2500 - root_mean_squared_error: 1363.7805 - mean_absolute_error: 1034.9221 - val_loss: 1796500.3750 - val_root_mean_squared_error: 1340.3359 - val_mean_absolute_error: 1005.0508
# Epoch 68/100
# 54/54 [==============================] - 1s 17ms/step - loss: 1833416.8750 - root_mean_squared_error: 1354.0372 - mean_absolute_error: 1026.6793 - val_loss: 1768315.0000 - val_root_mean_squared_error: 1329.7800 - val_mean_absolute_error: 1002.8368
# Epoch 69/100
# 54/54 [==============================] - 1s 23ms/step - loss: 1842147.6250 - root_mean_squared_error: 1357.2574 - mean_absolute_error: 1025.8817 - val_loss: 1755034.0000 - val_root_mean_squared_error: 1324.7770 - val_mean_absolute_error: 1000.7056
# Epoch 70/100
# 54/54 [==============================] - 1s 23ms/step - loss: 1805436.1250 - root_mean_squared_error: 1343.6652 - mean_absolute_error: 1017.1426 - val_loss: 1718470.3750 - val_root_mean_squared_error: 1310.9044 - val_mean_absolute_error: 974.1176
# Epoch 71/100
# 54/54 [==============================] - 1s 21ms/step - loss: 1789443.7500 - root_mean_squared_error: 1337.7009 - mean_absolute_error: 1013.6899 - val_loss: 1696286.5000 - val_root_mean_squared_error: 1302.4156 - val_mean_absolute_error: 972.1609
# Epoch 72/100
# 54/54 [==============================] - 1s 18ms/step - loss: 1788803.8750 - root_mean_squared_error: 1337.4617 - mean_absolute_error: 1008.6802 - val_loss: 1669519.7500 - val_root_mean_squared_error: 1292.0990 - val_mean_absolute_error: 961.4358
# Epoch 73/100
# 54/54 [==============================] - 1s 20ms/step - loss: 1744973.8750 - root_mean_squared_error: 1320.9746 - mean_absolute_error: 995.4511 - val_loss: 1645787.8750 - val_root_mean_squared_error: 1282.8827 - val_mean_absolute_error: 957.9330
# Epoch 74/100
# 54/54 [==============================] - 2s 29ms/step - loss: 1727088.2500 - root_mean_squared_error: 1314.1873 - mean_absolute_error: 985.4844 - val_loss: 1622729.6250 - val_root_mean_squared_error: 1273.8640 - val_mean_absolute_error: 944.3069
# Epoch 75/100
# 54/54 [==============================] - 2s 28ms/step - loss: 1739800.6250 - root_mean_squared_error: 1319.0150 - mean_absolute_error: 992.6605 - val_loss: 1596259.1250 - val_root_mean_squared_error: 1263.4315 - val_mean_absolute_error: 944.7874
# Epoch 76/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1683551.7500 - root_mean_squared_error: 1297.5176 - mean_absolute_error: 972.2476 - val_loss: 1578240.8750 - val_root_mean_squared_error: 1256.2805 - val_mean_absolute_error: 926.2825
# Epoch 77/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1677380.8750 - root_mean_squared_error: 1295.1375 - mean_absolute_error: 968.3091 - val_loss: 1569949.8750 - val_root_mean_squared_error: 1252.9764 - val_mean_absolute_error: 936.0778
# Epoch 78/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1663728.7500 - root_mean_squared_error: 1289.8561 - mean_absolute_error: 969.4454 - val_loss: 1589901.6250 - val_root_mean_squared_error: 1260.9130 - val_mean_absolute_error: 910.0288
# Epoch 79/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1719885.1250 - root_mean_squared_error: 1311.4438 - mean_absolute_error: 980.7548 - val_loss: 1524186.3750 - val_root_mean_squared_error: 1234.5795 - val_mean_absolute_error: 906.9623
# Epoch 80/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1643798.6250 - root_mean_squared_error: 1282.1071 - mean_absolute_error: 958.8307 - val_loss: 1515134.0000 - val_root_mean_squared_error: 1230.9078 - val_mean_absolute_error: 902.3124
# Epoch 81/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1625497.6250 - root_mean_squared_error: 1274.9501 - mean_absolute_error: 955.3344 - val_loss: 1505564.1250 - val_root_mean_squared_error: 1227.0143 - val_mean_absolute_error: 899.7428
# Epoch 82/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1627772.6250 - root_mean_squared_error: 1275.8419 - mean_absolute_error: 951.6686 - val_loss: 1493450.3750 - val_root_mean_squared_error: 1222.0681 - val_mean_absolute_error: 900.9755
# Epoch 83/100
# 54/54 [==============================] - 1s 10ms/step - loss: 1636725.1250 - root_mean_squared_error: 1279.3456 - mean_absolute_error: 951.7147 - val_loss: 1485844.5000 - val_root_mean_squared_error: 1218.9523 - val_mean_absolute_error: 887.6876
# Epoch 84/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1608327.8750 - root_mean_squared_error: 1268.1987 - mean_absolute_error: 949.1397 - val_loss: 1495178.6250 - val_root_mean_squared_error: 1222.7750 - val_mean_absolute_error: 874.0710
# Epoch 85/100
# 54/54 [==============================] - 1s 15ms/step - loss: 1611498.0000 - root_mean_squared_error: 1269.4479 - mean_absolute_error: 948.6674 - val_loss: 1446632.3750 - val_root_mean_squared_error: 1202.7603 - val_mean_absolute_error: 892.4922
# Epoch 86/100
# 54/54 [==============================] - 1s 19ms/step - loss: 1586957.0000 - root_mean_squared_error: 1259.7449 - mean_absolute_error: 940.5529 - val_loss: 1450585.3750 - val_root_mean_squared_error: 1204.4025 - val_mean_absolute_error: 865.2034
# Epoch 87/100
# 54/54 [==============================] - 1s 19ms/step - loss: 1561414.8750 - root_mean_squared_error: 1249.5659 - mean_absolute_error: 928.4437 - val_loss: 1452123.0000 - val_root_mean_squared_error: 1205.0406 - val_mean_absolute_error: 862.1505
# Epoch 88/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1577493.5000 - root_mean_squared_error: 1255.9830 - mean_absolute_error: 933.1187 - val_loss: 1413459.3750 - val_root_mean_squared_error: 1188.8900 - val_mean_absolute_error: 863.7984
# Epoch 89/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1557477.0000 - root_mean_squared_error: 1247.9891 - mean_absolute_error: 926.0817 - val_loss: 1423390.0000 - val_root_mean_squared_error: 1193.0591 - val_mean_absolute_error: 851.5376
# Epoch 90/100
# 54/54 [==============================] - 1s 13ms/step - loss: 1540397.7500 - root_mean_squared_error: 1241.1276 - mean_absolute_error: 914.2083 - val_loss: 1390672.8750 - val_root_mean_squared_error: 1179.2679 - val_mean_absolute_error: 845.7320
# Epoch 91/100
# 54/54 [==============================] - 1s 15ms/step - loss: 1539834.6250 - root_mean_squared_error: 1240.9008 - mean_absolute_error: 913.3774 - val_loss: 1386292.8750 - val_root_mean_squared_error: 1177.4094 - val_mean_absolute_error: 868.4781
# Epoch 92/100
# 54/54 [==============================] - 1s 16ms/step - loss: 1514607.3750 - root_mean_squared_error: 1230.6938 - mean_absolute_error: 909.0170 - val_loss: 1356445.6250 - val_root_mean_squared_error: 1164.6654 - val_mean_absolute_error: 834.0676
# Epoch 93/100
# 54/54 [==============================] - 1s 15ms/step - loss: 1500725.0000 - root_mean_squared_error: 1225.0408 - mean_absolute_error: 903.6703 - val_loss: 1353034.3750 - val_root_mean_squared_error: 1163.2001 - val_mean_absolute_error: 849.1710
# Epoch 94/100
# 54/54 [==============================] - 1s 14ms/step - loss: 1532838.7500 - root_mean_squared_error: 1238.0786 - mean_absolute_error: 912.2681 - val_loss: 1359366.6250 - val_root_mean_squared_error: 1165.9188 - val_mean_absolute_error: 858.4655
# Epoch 95/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1537498.3750 - root_mean_squared_error: 1239.9590 - mean_absolute_error: 912.3107 - val_loss: 1357226.3750 - val_root_mean_squared_error: 1165.0006 - val_mean_absolute_error: 854.8754
# Epoch 96/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1519923.0000 - root_mean_squared_error: 1232.8516 - mean_absolute_error: 902.2818 - val_loss: 1331412.5000 - val_root_mean_squared_error: 1153.8685 - val_mean_absolute_error: 823.6686
# Epoch 97/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1474555.7500 - root_mean_squared_error: 1214.3129 - mean_absolute_error: 892.6944 - val_loss: 1334231.6250 - val_root_mean_squared_error: 1155.0895 - val_mean_absolute_error: 842.1392
# Epoch 98/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1474159.8750 - root_mean_squared_error: 1214.1499 - mean_absolute_error: 888.2565 - val_loss: 1318415.3750 - val_root_mean_squared_error: 1148.2227 - val_mean_absolute_error: 835.1600
# Epoch 99/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1469522.5000 - root_mean_squared_error: 1212.2386 - mean_absolute_error: 887.5316 - val_loss: 1315232.6250 - val_root_mean_squared_error: 1146.8359 - val_mean_absolute_error: 811.5189
# Epoch 100/100
# 54/54 [==============================] - 1s 11ms/step - loss: 1469335.1250 - root_mean_squared_error: 1212.1614 - mean_absolute_error: 884.5181 - val_loss: 1308728.7500 - val_root_mean_squared_error: 1143.9968 - val_mean_absolute_error: 816.8652

# %%
import matplotlib.pyplot as plt

# Extract the metrics from the history object
root_mean_squared_error = history.history['root_mean_squared_error']
mean_absolute_error = history.history['mean_absolute_error']
val_root_mean_squared_error = history.history['val_root_mean_squared_error']
val_mean_absolute_error = history.history['val_mean_absolute_error']

# Plot the metrics
epochs = range(1, len(root_mean_squared_error) + 1)

plt.plot(epochs, root_mean_squared_error, 'b', label='Training RMSE')
plt.plot(epochs, mean_absolute_error, 'g', label='Training MAE')
plt.plot(epochs, val_root_mean_squared_error, 'r', label='Validation RMSE')
plt.plot(epochs, val_mean_absolute_error, 'm', label='Validation MAE')

plt.title('Training and Validation Metrics')
plt.xlabel('Epochs')
plt.ylabel('Metrics')
plt.legend()

plt.show()

# %%
#improved 1dcnn and lstm
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError
import tensorflow as tf

def get_model(params, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size=params["kernel_size"], activation=params["activation"], input_shape=(input_shape, 1)))
    model.add(MaxPooling1D(pool_size=params["pool_size"]))

    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dropout(rate=params["dropout"]))

    model.add(Flatten())
    model.add(Dense(units=64, activation=params["activation"]))
    model.add(Dropout(rate=params["dropout"]))

    model.add(Dense(units=1, activation=params["output_activation"]))

    model.compile(loss=params["loss"],
                  optimizer=tf.keras.optimizers.Adam(learning_rate=params["learning_rate"]),
                  metrics=[RootMeanSquaredError(), MeanAbsoluteError()])

    return model

params = {
    "loss": "mean_squared_error",
    "activation": "relu",
    "output_activation": "linear",
    "learning_rate": 0.001,
    "dropout": 0.3,
    "kernel_size": 3,
    "pool_size": 2,
    "epochs": 100,
    "batch_size": 128,
    "es_patience": 20
}

model = get_model(params=params, input_shape=x_train.shape[1])

es_callback = EarlyStopping(monitor='val_root_mean_squared_error',
                            mode='min',
                            patience=params["es_patience"])

history = model.fit(x_train,
                    y_train,
                    validation_data=(x_test, y_test),
                    epochs=params["epochs"],
                    batch_size=params["batch_size"],
                    verbose=1,
                    callbacks=[es_callback])
# Out:
# Epoch 1/100
# 54/54 [==============================] - 4s 28ms/step - loss: 7428906.5000 - root_mean_squared_error: 2725.6021 - mean_absolute_error: 2129.4541 - val_loss: 6848133.5000 - val_root_mean_squared_error: 2616.8938 - val_mean_absolute_error: 1973.3506
# Epoch 2/100
# 54/54 [==============================] - 1s 19ms/step - loss: 6045967.5000 - root_mean_squared_error: 2458.8550 - mean_absolute_error: 1819.3344 - val_loss: 5162362.5000 - val_root_mean_squared_error: 2272.0833 - val_mean_absolute_error: 1619.9353
# Epoch 3/100
# 54/54 [==============================] - 1s 23ms/step - loss: 4412428.0000 - root_mean_squared_error: 2100.5781 - mean_absolute_error: 1498.5007 - val_loss: 3763290.5000 - val_root_mean_squared_error: 1939.9203 - val_mean_absolute_error: 1384.7045
# Epoch 4/100
# 54/54 [==============================] - 2s 31ms/step - loss: 3361078.0000 - root_mean_squared_error: 1833.3243 - mean_absolute_error: 1336.1722 - val_loss: 3136748.2500 - val_root_mean_squared_error: 1771.0868 - val_mean_absolute_error: 1321.6901
# Epoch 5/100
# 54/54 [==============================] - 1s 26ms/step - loss: 2996227.5000 - root_mean_squared_error: 1730.9614 - mean_absolute_error: 1322.4297 - val_loss: 2996870.5000 - val_root_mean_squared_error: 1731.1472 - val_mean_absolute_error: 1338.3213
# Epoch 6/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2939802.2500 - root_mean_squared_error: 1714.5852 - mean_absolute_error: 1336.8290 - val_loss: 2979618.5000 - val_root_mean_squared_error: 1726.1571 - val_mean_absolute_error: 1352.0741
# Epoch 7/100
# 54/54 [==============================] - 1s 19ms/step - loss: 2974445.0000 - root_mean_squared_error: 1724.6580 - mean_absolute_error: 1357.1823 - val_loss: 2977677.0000 - val_root_mean_squared_error: 1725.5947 - val_mean_absolute_error: 1352.0129
# Epoch 8/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2938812.2500 - root_mean_squared_error: 1714.2964 - mean_absolute_error: 1345.9988 - val_loss: 2975601.7500 - val_root_mean_squared_error: 1724.9933 - val_mean_absolute_error: 1353.4486
# Epoch 9/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2935945.7500 - root_mean_squared_error: 1713.4602 - mean_absolute_error: 1349.6985 - val_loss: 2973529.7500 - val_root_mean_squared_error: 1724.3926 - val_mean_absolute_error: 1351.9337
# Epoch 10/100
# 54/54 [==============================] - 1s 19ms/step - loss: 2945875.7500 - root_mean_squared_error: 1716.3553 - mean_absolute_error: 1349.7429 - val_loss: 2971517.0000 - val_root_mean_squared_error: 1723.8088 - val_mean_absolute_error: 1352.5918
# Epoch 11/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2918913.2500 - root_mean_squared_error: 1708.4828 - mean_absolute_error: 1346.6168 - val_loss: 2969725.5000 - val_root_mean_squared_error: 1723.2892 - val_mean_absolute_error: 1349.7983
# Epoch 12/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2941208.7500 - root_mean_squared_error: 1714.9952 - mean_absolute_error: 1346.1200 - val_loss: 2966792.5000 - val_root_mean_squared_error: 1722.4380 - val_mean_absolute_error: 1351.9851
# Epoch 13/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2927132.0000 - root_mean_squared_error: 1710.8864 - mean_absolute_error: 1341.1407 - val_loss: 2965327.5000 - val_root_mean_squared_error: 1722.0126 - val_mean_absolute_error: 1352.3171
# Epoch 14/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2938884.2500 - root_mean_squared_error: 1714.3174 - mean_absolute_error: 1346.4496 - val_loss: 2962676.0000 - val_root_mean_squared_error: 1721.2426 - val_mean_absolute_error: 1351.7368
# Epoch 15/100
# 54/54 [==============================] - 2s 31ms/step - loss: 2930049.7500 - root_mean_squared_error: 1711.7388 - mean_absolute_error: 1348.1473 - val_loss: 2958697.5000 - val_root_mean_squared_error: 1720.0864 - val_mean_absolute_error: 1348.8292
# Epoch 16/100
# 54/54 [==============================] - 2s 30ms/step - loss: 2927469.0000 - root_mean_squared_error: 1710.9849 - mean_absolute_error: 1343.0017 - val_loss: 2955313.2500 - val_root_mean_squared_error: 1719.1024 - val_mean_absolute_error: 1350.3711
# Epoch 17/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2927358.7500 - root_mean_squared_error: 1710.9526 - mean_absolute_error: 1350.5717 - val_loss: 2952675.7500 - val_root_mean_squared_error: 1718.3352 - val_mean_absolute_error: 1347.7832
# Epoch 18/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2922416.7500 - root_mean_squared_error: 1709.5077 - mean_absolute_error: 1341.8065 - val_loss: 2949244.5000 - val_root_mean_squared_error: 1717.3364 - val_mean_absolute_error: 1345.6168
# Epoch 19/100
# 54/54 [==============================] - 2s 28ms/step - loss: 2930073.5000 - root_mean_squared_error: 1711.7457 - mean_absolute_error: 1345.7418 - val_loss: 2946114.5000 - val_root_mean_squared_error: 1716.4249 - val_mean_absolute_error: 1344.9148
# Epoch 20/100
# 54/54 [==============================] - 2s 34ms/step - loss: 2917744.2500 - root_mean_squared_error: 1708.1406 - mean_absolute_error: 1343.6180 - val_loss: 2942219.0000 - val_root_mean_squared_error: 1715.2898 - val_mean_absolute_error: 1347.5697
# Epoch 21/100
# 54/54 [==============================] - 2s 38ms/step - loss: 2915164.5000 - root_mean_squared_error: 1707.3853 - mean_absolute_error: 1344.3439 - val_loss: 2937500.0000 - val_root_mean_squared_error: 1713.9137 - val_mean_absolute_error: 1344.3634
# Epoch 22/100
# 54/54 [==============================] - 2s 39ms/step - loss: 2905716.2500 - root_mean_squared_error: 1704.6162 - mean_absolute_error: 1339.9919 - val_loss: 2932869.7500 - val_root_mean_squared_error: 1712.5624 - val_mean_absolute_error: 1339.1646
# Epoch 23/100
# 54/54 [==============================] - 2s 33ms/step - loss: 2899050.7500 - root_mean_squared_error: 1702.6599 - mean_absolute_error: 1334.5382 - val_loss: 2927656.2500 - val_root_mean_squared_error: 1711.0396 - val_mean_absolute_error: 1346.5710
# Epoch 24/100
# 54/54 [==============================] - 2s 29ms/step - loss: 2902857.2500 - root_mean_squared_error: 1703.7773 - mean_absolute_error: 1341.3824 - val_loss: 2921377.5000 - val_root_mean_squared_error: 1709.2037 - val_mean_absolute_error: 1340.9113
# Epoch 25/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2900486.5000 - root_mean_squared_error: 1703.0814 - mean_absolute_error: 1337.9592 - val_loss: 2916794.7500 - val_root_mean_squared_error: 1707.8627 - val_mean_absolute_error: 1338.7808
# Epoch 26/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2871737.5000 - root_mean_squared_error: 1694.6201 - mean_absolute_error: 1332.0123 - val_loss: 2910834.0000 - val_root_mean_squared_error: 1706.1167 - val_mean_absolute_error: 1336.2732
# Epoch 27/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2879371.7500 - root_mean_squared_error: 1696.8712 - mean_absolute_error: 1329.8921 - val_loss: 2902550.0000 - val_root_mean_squared_error: 1703.6871 - val_mean_absolute_error: 1338.5983
# Epoch 28/100
# 54/54 [==============================] - 1s 19ms/step - loss: 2859701.2500 - root_mean_squared_error: 1691.0651 - mean_absolute_error: 1333.0854 - val_loss: 2896701.2500 - val_root_mean_squared_error: 1701.9698 - val_mean_absolute_error: 1333.5065
# Epoch 29/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2862149.2500 - root_mean_squared_error: 1691.7888 - mean_absolute_error: 1331.5806 - val_loss: 2890463.7500 - val_root_mean_squared_error: 1700.1364 - val_mean_absolute_error: 1330.1047
# Epoch 30/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2863464.5000 - root_mean_squared_error: 1692.1775 - mean_absolute_error: 1327.8862 - val_loss: 2885716.5000 - val_root_mean_squared_error: 1698.7396 - val_mean_absolute_error: 1325.8395
# Epoch 31/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2857852.5000 - root_mean_squared_error: 1690.5184 - mean_absolute_error: 1326.9426 - val_loss: 2879721.0000 - val_root_mean_squared_error: 1696.9741 - val_mean_absolute_error: 1326.1708
# Epoch 32/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2837844.5000 - root_mean_squared_error: 1684.5903 - mean_absolute_error: 1320.0314 - val_loss: 2872934.7500 - val_root_mean_squared_error: 1694.9734 - val_mean_absolute_error: 1331.5022
# Epoch 33/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2847108.5000 - root_mean_squared_error: 1687.3376 - mean_absolute_error: 1323.4954 - val_loss: 2866134.2500 - val_root_mean_squared_error: 1692.9661 - val_mean_absolute_error: 1326.0336
# Epoch 34/100
# 54/54 [==============================] - 2s 32ms/step - loss: 2826032.2500 - root_mean_squared_error: 1681.0807 - mean_absolute_error: 1321.1415 - val_loss: 2860470.0000 - val_root_mean_squared_error: 1691.2924 - val_mean_absolute_error: 1326.0024
# Epoch 35/100
# 54/54 [==============================] - 2s 28ms/step - loss: 2820285.7500 - root_mean_squared_error: 1679.3706 - mean_absolute_error: 1317.5612 - val_loss: 2852505.5000 - val_root_mean_squared_error: 1688.9362 - val_mean_absolute_error: 1320.1671
# Epoch 36/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2827770.2500 - root_mean_squared_error: 1681.5975 - mean_absolute_error: 1320.3547 - val_loss: 2845564.7500 - val_root_mean_squared_error: 1686.8801 - val_mean_absolute_error: 1319.9938
# Epoch 37/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2815034.7500 - root_mean_squared_error: 1677.8065 - mean_absolute_error: 1317.2255 - val_loss: 2840717.2500 - val_root_mean_squared_error: 1685.4427 - val_mean_absolute_error: 1322.2673
# Epoch 38/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2825913.0000 - root_mean_squared_error: 1681.0452 - mean_absolute_error: 1318.9158 - val_loss: 2830902.0000 - val_root_mean_squared_error: 1682.5284 - val_mean_absolute_error: 1316.5610
# Epoch 39/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2786409.0000 - root_mean_squared_error: 1669.2540 - mean_absolute_error: 1312.1349 - val_loss: 2824485.5000 - val_root_mean_squared_error: 1680.6206 - val_mean_absolute_error: 1312.3612
# Epoch 40/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2782794.0000 - root_mean_squared_error: 1668.1709 - mean_absolute_error: 1312.0326 - val_loss: 2818468.7500 - val_root_mean_squared_error: 1678.8296 - val_mean_absolute_error: 1312.0176
# Epoch 41/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2796533.2500 - root_mean_squared_error: 1672.2838 - mean_absolute_error: 1312.6312 - val_loss: 2809159.0000 - val_root_mean_squared_error: 1676.0546 - val_mean_absolute_error: 1308.3191
# Epoch 42/100
# 54/54 [==============================] - 1s 19ms/step - loss: 2771139.5000 - root_mean_squared_error: 1664.6740 - mean_absolute_error: 1308.4584 - val_loss: 2803164.7500 - val_root_mean_squared_error: 1674.2654 - val_mean_absolute_error: 1307.1334
# Epoch 43/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2763277.0000 - root_mean_squared_error: 1662.3108 - mean_absolute_error: 1302.9434 - val_loss: 2793692.0000 - val_root_mean_squared_error: 1671.4341 - val_mean_absolute_error: 1303.0730
# Epoch 44/100
# 54/54 [==============================] - 1s 19ms/step - loss: 2756979.7500 - root_mean_squared_error: 1660.4155 - mean_absolute_error: 1297.8809 - val_loss: 2784947.0000 - val_root_mean_squared_error: 1668.8160 - val_mean_absolute_error: 1302.2277
# Epoch 45/100
# 54/54 [==============================] - 2s 31ms/step - loss: 2757085.0000 - root_mean_squared_error: 1660.4473 - mean_absolute_error: 1303.3458 - val_loss: 2775762.5000 - val_root_mean_squared_error: 1666.0620 - val_mean_absolute_error: 1300.6661
# Epoch 46/100
# 54/54 [==============================] - 2s 30ms/step - loss: 2727642.7500 - root_mean_squared_error: 1651.5576 - mean_absolute_error: 1293.2108 - val_loss: 2766613.7500 - val_root_mean_squared_error: 1663.3141 - val_mean_absolute_error: 1300.7299
# Epoch 47/100
# 54/54 [==============================] - 1s 19ms/step - loss: 2734127.7500 - root_mean_squared_error: 1653.5198 - mean_absolute_error: 1295.8234 - val_loss: 2757174.0000 - val_root_mean_squared_error: 1660.4740 - val_mean_absolute_error: 1294.8374
# Epoch 48/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2716082.0000 - root_mean_squared_error: 1648.0540 - mean_absolute_error: 1285.5710 - val_loss: 2749118.2500 - val_root_mean_squared_error: 1658.0465 - val_mean_absolute_error: 1299.1456
# Epoch 49/100
# 54/54 [==============================] - 1s 19ms/step - loss: 2735277.2500 - root_mean_squared_error: 1653.8673 - mean_absolute_error: 1297.9562 - val_loss: 2736231.0000 - val_root_mean_squared_error: 1654.1556 - val_mean_absolute_error: 1289.4338
# Epoch 50/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2715603.2500 - root_mean_squared_error: 1647.9087 - mean_absolute_error: 1292.9197 - val_loss: 2725706.2500 - val_root_mean_squared_error: 1650.9713 - val_mean_absolute_error: 1287.8245
# Epoch 51/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2679721.5000 - root_mean_squared_error: 1636.9855 - mean_absolute_error: 1283.2795 - val_loss: 2713367.0000 - val_root_mean_squared_error: 1647.2301 - val_mean_absolute_error: 1288.0961
# Epoch 52/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2694485.2500 - root_mean_squared_error: 1641.4888 - mean_absolute_error: 1287.9611 - val_loss: 2699807.2500 - val_root_mean_squared_error: 1643.1090 - val_mean_absolute_error: 1280.7500
# Epoch 53/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2680377.0000 - root_mean_squared_error: 1637.1857 - mean_absolute_error: 1287.3782 - val_loss: 2690620.0000 - val_root_mean_squared_error: 1640.3109 - val_mean_absolute_error: 1274.0651
# Epoch 54/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2662338.2500 - root_mean_squared_error: 1631.6674 - mean_absolute_error: 1275.1031 - val_loss: 2675726.5000 - val_root_mean_squared_error: 1635.7648 - val_mean_absolute_error: 1273.7919
# Epoch 55/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2643734.5000 - root_mean_squared_error: 1625.9565 - mean_absolute_error: 1267.0094 - val_loss: 2660343.5000 - val_root_mean_squared_error: 1631.0559 - val_mean_absolute_error: 1270.9750
# Epoch 56/100
# 54/54 [==============================] - 2s 28ms/step - loss: 2624368.2500 - root_mean_squared_error: 1619.9902 - mean_absolute_error: 1268.9633 - val_loss: 2651223.2500 - val_root_mean_squared_error: 1628.2577 - val_mean_absolute_error: 1267.8533
# Epoch 57/100
# 54/54 [==============================] - 2s 31ms/step - loss: 2629358.2500 - root_mean_squared_error: 1621.5295 - mean_absolute_error: 1266.1375 - val_loss: 2637831.0000 - val_root_mean_squared_error: 1624.1401 - val_mean_absolute_error: 1259.7184
# Epoch 58/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2595098.0000 - root_mean_squared_error: 1610.9308 - mean_absolute_error: 1258.7299 - val_loss: 2621545.0000 - val_root_mean_squared_error: 1619.1185 - val_mean_absolute_error: 1262.3016
# Epoch 59/100
# 54/54 [==============================] - 1s 26ms/step - loss: 2598228.7500 - root_mean_squared_error: 1611.9022 - mean_absolute_error: 1254.2175 - val_loss: 2606861.5000 - val_root_mean_squared_error: 1614.5778 - val_mean_absolute_error: 1260.4030
# Epoch 60/100
# 54/54 [==============================] - 2s 31ms/step - loss: 2598787.0000 - root_mean_squared_error: 1612.0753 - mean_absolute_error: 1255.8781 - val_loss: 2590731.7500 - val_root_mean_squared_error: 1609.5751 - val_mean_absolute_error: 1252.1023
# Epoch 61/100
# 54/54 [==============================] - 1s 22ms/step - loss: 2552606.2500 - root_mean_squared_error: 1597.6877 - mean_absolute_error: 1250.7156 - val_loss: 2595111.5000 - val_root_mean_squared_error: 1610.9349 - val_mean_absolute_error: 1238.3101
# Epoch 62/100
# 54/54 [==============================] - 1s 19ms/step - loss: 2556349.0000 - root_mean_squared_error: 1598.8586 - mean_absolute_error: 1244.0990 - val_loss: 2572039.2500 - val_root_mean_squared_error: 1603.7578 - val_mean_absolute_error: 1249.6256
# Epoch 63/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2529386.0000 - root_mean_squared_error: 1590.4043 - mean_absolute_error: 1238.9862 - val_loss: 2541379.5000 - val_root_mean_squared_error: 1594.1705 - val_mean_absolute_error: 1240.0186
# Epoch 64/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2531151.2500 - root_mean_squared_error: 1590.9592 - mean_absolute_error: 1237.1465 - val_loss: 2524704.0000 - val_root_mean_squared_error: 1588.9318 - val_mean_absolute_error: 1239.6050
# Epoch 65/100
# 54/54 [==============================] - 1s 19ms/step - loss: 2494365.7500 - root_mean_squared_error: 1579.3561 - mean_absolute_error: 1227.3983 - val_loss: 2507933.7500 - val_root_mean_squared_error: 1583.6458 - val_mean_absolute_error: 1232.3755
# Epoch 66/100
# 54/54 [==============================] - 1s 25ms/step - loss: 2478317.5000 - root_mean_squared_error: 1574.2673 - mean_absolute_error: 1228.1710 - val_loss: 2496892.2500 - val_root_mean_squared_error: 1580.1558 - val_mean_absolute_error: 1229.2468
# Epoch 67/100
# 54/54 [==============================] - 2s 30ms/step - loss: 2470513.7500 - root_mean_squared_error: 1571.7867 - mean_absolute_error: 1220.9393 - val_loss: 2473020.7500 - val_root_mean_squared_error: 1572.5841 - val_mean_absolute_error: 1220.6321
# Epoch 68/100
# 54/54 [==============================] - 1s 25ms/step - loss: 2457946.5000 - root_mean_squared_error: 1567.7839 - mean_absolute_error: 1220.0986 - val_loss: 2460114.0000 - val_root_mean_squared_error: 1568.4751 - val_mean_absolute_error: 1217.8751
# Epoch 69/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2421316.2500 - root_mean_squared_error: 1556.0579 - mean_absolute_error: 1205.1449 - val_loss: 2441478.0000 - val_root_mean_squared_error: 1562.5229 - val_mean_absolute_error: 1205.0441
# Epoch 70/100
# 54/54 [==============================] - 1s 19ms/step - loss: 2384648.0000 - root_mean_squared_error: 1544.2306 - mean_absolute_error: 1203.6674 - val_loss: 2419576.0000 - val_root_mean_squared_error: 1555.4987 - val_mean_absolute_error: 1200.0635
# Epoch 71/100
# 54/54 [==============================] - 1s 19ms/step - loss: 2400630.7500 - root_mean_squared_error: 1549.3969 - mean_absolute_error: 1204.6932 - val_loss: 2404482.5000 - val_root_mean_squared_error: 1550.6394 - val_mean_absolute_error: 1191.9335
# Epoch 72/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2380671.2500 - root_mean_squared_error: 1542.9424 - mean_absolute_error: 1195.4846 - val_loss: 2382368.7500 - val_root_mean_squared_error: 1543.4924 - val_mean_absolute_error: 1189.3252
# Epoch 73/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2379558.5000 - root_mean_squared_error: 1542.5818 - mean_absolute_error: 1195.2572 - val_loss: 2364682.7500 - val_root_mean_squared_error: 1537.7524 - val_mean_absolute_error: 1187.8118
# Epoch 74/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2344900.7500 - root_mean_squared_error: 1531.3069 - mean_absolute_error: 1191.4064 - val_loss: 2348255.5000 - val_root_mean_squared_error: 1532.4019 - val_mean_absolute_error: 1184.5258
# Epoch 75/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2316877.7500 - root_mean_squared_error: 1522.1294 - mean_absolute_error: 1181.0966 - val_loss: 2327938.2500 - val_root_mean_squared_error: 1525.7583 - val_mean_absolute_error: 1177.0122
# Epoch 76/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2326805.7500 - root_mean_squared_error: 1525.3871 - mean_absolute_error: 1181.7078 - val_loss: 2310133.2500 - val_root_mean_squared_error: 1519.9122 - val_mean_absolute_error: 1167.6669
# Epoch 77/100
# 54/54 [==============================] - 1s 23ms/step - loss: 2302669.5000 - root_mean_squared_error: 1517.4550 - mean_absolute_error: 1173.5784 - val_loss: 2298997.5000 - val_root_mean_squared_error: 1516.2445 - val_mean_absolute_error: 1176.6989
# Epoch 78/100
# 54/54 [==============================] - 2s 33ms/step - loss: 2266364.2500 - root_mean_squared_error: 1505.4448 - mean_absolute_error: 1169.3071 - val_loss: 2278204.5000 - val_root_mean_squared_error: 1509.3722 - val_mean_absolute_error: 1158.2159
# Epoch 79/100
# 54/54 [==============================] - 2s 35ms/step - loss: 2244014.7500 - root_mean_squared_error: 1498.0035 - mean_absolute_error: 1158.7385 - val_loss: 2265466.7500 - val_root_mean_squared_error: 1505.1467 - val_mean_absolute_error: 1158.7404
# Epoch 80/100
# 54/54 [==============================] - 1s 25ms/step - loss: 2246670.2500 - root_mean_squared_error: 1498.8896 - mean_absolute_error: 1161.8037 - val_loss: 2249634.7500 - val_root_mean_squared_error: 1499.8783 - val_mean_absolute_error: 1150.9148
# Epoch 81/100
# 54/54 [==============================] - 1s 28ms/step - loss: 2234403.0000 - root_mean_squared_error: 1494.7920 - mean_absolute_error: 1156.1940 - val_loss: 2225557.7500 - val_root_mean_squared_error: 1491.8303 - val_mean_absolute_error: 1148.0311
# Epoch 82/100
# 54/54 [==============================] - 2s 34ms/step - loss: 2214152.0000 - root_mean_squared_error: 1488.0027 - mean_absolute_error: 1148.6193 - val_loss: 2216214.2500 - val_root_mean_squared_error: 1488.6954 - val_mean_absolute_error: 1144.5765
# Epoch 83/100
# 54/54 [==============================] - 2s 28ms/step - loss: 2184500.2500 - root_mean_squared_error: 1478.0055 - mean_absolute_error: 1143.4755 - val_loss: 2192833.7500 - val_root_mean_squared_error: 1480.8220 - val_mean_absolute_error: 1142.9576
# Epoch 84/100
# 54/54 [==============================] - 1s 20ms/step - loss: 2210933.0000 - root_mean_squared_error: 1486.9207 - mean_absolute_error: 1151.6355 - val_loss: 2182891.0000 - val_root_mean_squared_error: 1477.4609 - val_mean_absolute_error: 1128.8730
# Epoch 85/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2176918.5000 - root_mean_squared_error: 1475.4384 - mean_absolute_error: 1138.7468 - val_loss: 2182375.2500 - val_root_mean_squared_error: 1477.2865 - val_mean_absolute_error: 1126.5732
# Epoch 86/100
# 54/54 [==============================] - 1s 22ms/step - loss: 2180099.5000 - root_mean_squared_error: 1476.5160 - mean_absolute_error: 1132.5901 - val_loss: 2151315.0000 - val_root_mean_squared_error: 1466.7362 - val_mean_absolute_error: 1131.2393
# Epoch 87/100
# 54/54 [==============================] - 2s 32ms/step - loss: 2174112.0000 - root_mean_squared_error: 1474.4871 - mean_absolute_error: 1135.6943 - val_loss: 2138350.0000 - val_root_mean_squared_error: 1462.3098 - val_mean_absolute_error: 1119.7131
# Epoch 88/100
# 54/54 [==============================] - 2s 32ms/step - loss: 2149071.2500 - root_mean_squared_error: 1465.9711 - mean_absolute_error: 1130.3965 - val_loss: 2121784.5000 - val_root_mean_squared_error: 1456.6346 - val_mean_absolute_error: 1119.9115
# Epoch 89/100
# 54/54 [==============================] - 1s 22ms/step - loss: 2141706.7500 - root_mean_squared_error: 1463.4572 - mean_absolute_error: 1130.3805 - val_loss: 2124416.0000 - val_root_mean_squared_error: 1457.5376 - val_mean_absolute_error: 1111.7711
# Epoch 90/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2112476.0000 - root_mean_squared_error: 1453.4359 - mean_absolute_error: 1117.8364 - val_loss: 2087727.5000 - val_root_mean_squared_error: 1444.8971 - val_mean_absolute_error: 1109.4873
# Epoch 91/100
# 54/54 [==============================] - 1s 22ms/step - loss: 2110100.5000 - root_mean_squared_error: 1452.6185 - mean_absolute_error: 1121.0985 - val_loss: 2099258.7500 - val_root_mean_squared_error: 1448.8818 - val_mean_absolute_error: 1119.9554
# Epoch 92/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2090319.6250 - root_mean_squared_error: 1445.7938 - mean_absolute_error: 1116.9194 - val_loss: 2063422.2500 - val_root_mean_squared_error: 1436.4617 - val_mean_absolute_error: 1104.8064
# Epoch 93/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2082291.7500 - root_mean_squared_error: 1443.0148 - mean_absolute_error: 1108.9301 - val_loss: 2048420.7500 - val_root_mean_squared_error: 1431.2305 - val_mean_absolute_error: 1100.1891
# Epoch 94/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2088678.7500 - root_mean_squared_error: 1445.2262 - mean_absolute_error: 1109.8455 - val_loss: 2048338.6250 - val_root_mean_squared_error: 1431.2018 - val_mean_absolute_error: 1089.5514
# Epoch 95/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2056855.0000 - root_mean_squared_error: 1434.1740 - mean_absolute_error: 1101.3606 - val_loss: 2029011.5000 - val_root_mean_squared_error: 1424.4337 - val_mean_absolute_error: 1087.5348
# Epoch 96/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2044309.8750 - root_mean_squared_error: 1429.7937 - mean_absolute_error: 1097.9386 - val_loss: 2009550.6250 - val_root_mean_squared_error: 1417.5862 - val_mean_absolute_error: 1085.8386
# Epoch 97/100
# 54/54 [==============================] - 1s 27ms/step - loss: 2039250.6250 - root_mean_squared_error: 1428.0233 - mean_absolute_error: 1093.3077 - val_loss: 2023583.8750 - val_root_mean_squared_error: 1422.5273 - val_mean_absolute_error: 1071.6378
# Epoch 98/100
# 54/54 [==============================] - 2s 33ms/step - loss: 2030162.3750 - root_mean_squared_error: 1424.8376 - mean_absolute_error: 1090.3392 - val_loss: 1987499.0000 - val_root_mean_squared_error: 1409.7869 - val_mean_absolute_error: 1082.7340
# Epoch 99/100
# 54/54 [==============================] - 1s 26ms/step - loss: 1997108.8750 - root_mean_squared_error: 1413.1910 - mean_absolute_error: 1086.8110 - val_loss: 1985054.8750 - val_root_mean_squared_error: 1408.9198 - val_mean_absolute_error: 1069.2592
# Epoch 100/100
# 54/54 [==============================] - 1s 21ms/step - loss: 2048738.5000 - root_mean_squared_error: 1431.3416 - mean_absolute_error: 1095.6019 - val_loss: 1961377.3750 - val_root_mean_squared_error: 1400.4918 - val_mean_absolute_error: 1074.8417

# %%
import matplotlib.pyplot as plt

# Extract the metrics from the history object
root_mean_squared_error = history.history['root_mean_squared_error']
mean_absolute_error = history.history['mean_absolute_error']
val_root_mean_squared_error = history.history['val_root_mean_squared_error']
val_mean_absolute_error = history.history['val_mean_absolute_error']

# Plot the metrics
epochs = range(1, len(root_mean_squared_error) + 1)

plt.plot(epochs, root_mean_squared_error, 'b', label='Training RMSE')
plt.plot(epochs, mean_absolute_error, 'g', label='Training MAE')
plt.plot(epochs, val_root_mean_squared_error, 'r', label='Validation RMSE')
plt.plot(epochs, val_mean_absolute_error, 'm', label='Validation MAE')

plt.title('Training and Validation Metrics')
plt.xlabel('Epochs')
plt.ylabel('Metrics')
plt.legend()

plt.show()
